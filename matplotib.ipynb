# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# matpotlib basic

# %%
x=np.linspace(0,5,12)
x
y=x
y=x**2
y
# Out:
# array([ 0.        ,  0.20661157,  0.82644628,  1.85950413,  3.30578512,
#         5.16528926,  7.43801653, 10.12396694, 13.2231405 , 16.73553719,
#        20.66115702, 25.        ])

# %%
x
# Out:
# array([0.        , 0.45454545, 0.90909091, 1.36363636, 1.81818182,
#        2.27272727, 2.72727273, 3.18181818, 3.63636364, 4.09090909,
#        4.54545455, 5.        ])

# %%
y
# Out:
# array([ 0.        ,  0.20661157,  0.82644628,  1.85950413,  3.30578512,
#         5.16528926,  7.43801653, 10.12396694, 13.2231405 , 16.73553719,
#        20.66115702, 25.        ])

# %%
plt.plot(x,y)

# %%
plt.title("priyanshu")
plt.xlabel("himanshu")
plt.ylabel("shivam")
# Out:
# Text(0, 0.5, 'shivam')

# %%
plt.subplot(2,2,1)
plt.plot(x,y)
plt.subplot(2,2,2)
plt.plot(x,x)
plt.subplot(2,2,3)
plt.plot(y,y)
plt.subplot(2,2,4)
plt.plot(x**2)
